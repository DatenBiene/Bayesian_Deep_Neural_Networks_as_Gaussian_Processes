# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import itertools

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10, 10

sns.set_style("darkgrid")

# %% [markdown]
# Mnist

# %%
nnpg_list = np.loadtxt('nngp_list3.txt')
full_accur_list = np.loadtxt('full_accur_list2.txt')

full_time_list = np.loadtxt('full_time_list2.txt')
size_hidden_layer = np.loadtxt('size_hidden_layer2.txt')
size_train_iter = np.loadtxt('size_train_iter2.txt')

# %%
nnpg_list
# Out:
# array([0.56 , 0.601, 0.65 , 0.711, 0.808, 0.878, 0.9  , 0.911, 0.922,
#        0.928])

# %%
size_train_iter
# Out:
# array([  10.,   20.,   50.,  100.,  250.,  500.,  750., 1000., 1500.,
#        2000.])

# %%
[str(s)[:-2] for s in size_train_iter]
# Out:
# ['10', '20', '50', '100', '250', '500', '750', '1000', '1500', '2000']

# %%
size_list = [str(s)[:-2] for s in size_train_iter]

for i, hl in enumerate(size_hidden_layer):
    plt.plot(size_list, full_accur_list[i], label=hl)
plt.plot(size_list, nnpg_list, label='nnpg', linewidth=5, color='black')
plt.legend()

# %%
for i, hl in enumerate(size_hidden_layer):
    plt.plot([str(s)[:-2] for s in size_train_iter], full_time_list[i], label=hl)
plt.legend()
